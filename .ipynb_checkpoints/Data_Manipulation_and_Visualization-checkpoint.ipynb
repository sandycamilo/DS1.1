# %%
import numpy as np 
import pandas as pd 

df = pd.read_csv('titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
# VARIABLE DESCRIPTIONS:
# survival        Survival
#                 (0 = No; 1 = Yes)
# pclass          Passenger Class
#                 (1 = 1st; 2 = 2nd; 3 = 3rd)
# name            Name
# sex             Sex
# age             Age
# sibsp           Number of Siblings/Spouses Aboard
# parch           Number of Parents/Children Aboard
# ticket          Ticket Number
# fare            Passenger Fare
# cabin           Cabin
# embarked        Port of Embarkation
#                 (C = Cherbourg; Q = Queenstown; S = Southampton)

# %%
import matplotlib.pyplot as plt

df['Age'].hist(bins=16)
plt.show()

# %%
# how many of Age values are null #177 passangers have no report of age. 
df['Age'].isna().sum()
# Out:
# 177

# %%
# create a new column as gender, when Sex is female it is zero when sex is male it is one
df['Gender'] = df['Sex'].map( {'female': 0, 'male': 1} ).astype(int)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Gender
# 0      0         A/5 21171   7.2500   NaN        S       1
# 1      0          PC 17599  71.2833   C85        C       0
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0
# 3      0            113803  53.1000  C123        S       0
# ...

# %%
df.shape
# Out:
# (891, 13)

# %%
df['Age'].plot.box()

# %%
#get rid of all null values
df['Age'].dropna().values
# Out:
# array([22.  , 38.  , 26.  , 35.  , 35.  , 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 14.  , 55.  ,  2.  , 31.  , 35.  ,
#        34.  , 15.  , 28.  ,  8.  , 38.  , 19.  , 40.  , 66.  , 28.  ,
#        42.  , 21.  , 18.  , 14.  , 40.  , 27.  ,  3.  , 19.  , 18.  ,
#         7.  , 21.  , 49.  , 29.  , 65.  , 21.  , 28.5 ,  5.  , 11.  ,
#        22.  , 38.  , 45.  ,  4.  , 29.  , 19.  , 17.  , 26.  , 32.  ,
#        16.  , 21.  , 26.  , 32.  , 25.  ,  0.83, 30.  , 22.  , 29.  ,
#        28.  , 17.  , 33.  , 16.  , 23.  , 24.  , 29.  , 20.  , 46.  ,
#        26.  , 59.  , 71.  , 23.  , 34.  , 34.  , 28.  , 21.  , 33.  ,
#        37.  , 28.  , 21.  , 38.  , 47.  , 14.5 , 22.  , 20.  , 17.  ,
#        21.  , 70.5 , 29.  , 24.  ,  2.  , 21.  , 32.5 , 32.5 , 54.  ,
#        12.  , 24.  , 45.  , 33.  , 20.  , 47.  , 29.  , 25.  , 23.  ,
#        19.  , 37.  , 16.  , 24.  , 22.  , 24.  , 19.  , 18.  , 19.  ,
# ...

# %%
# len(df) is total length of values and subtracting null values
len(df)-df['Age'].isna().sum()
# Out:
# 714

# %%
df[df['Embarked'] == 'C'].head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 9            10         1       2
# 19           20         1       3
# 26           27         0       3
# 30           31         0       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 19                            Masselmani, Mrs. Fatima  female   NaN      0
# 26                            Emir, Mr. Farred Chehab    male   NaN      0
# 30                           Uruchurtu, Don. Manuel E    male  40.0      0
#
#     Parch    Ticket     Fare Cabin Embarked  Gender
# 1       0  PC 17599  71.2833   C85        C       0
# 9       0    237736  30.0708   NaN        C       0
# 19      0      2649   7.2250   NaN        C       0
# 26      0      2631   7.2250   NaN        C       1
# ...

# %%
##How many passagenrs embarked at section C? 168.

df[df['Embarked'] == 'C']
# len(df[df['Embarked'] == 'C'])
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 9             10         1       2
# 19            20         1       3
# 26            27         0       3
# 30            31         0       1
# ..           ...       ...     ...
# 866          867         1       2
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# 26                             Emir, Mr. Farred Chehab    male   NaN      0
# 30                            Uruchurtu, Don. Manuel E    male  40.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#display all rows
pd.set_option('display.max_rows', None)

# %%
df.head
# Out:
# <bound method NDFrame.head of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
# Plot the age range for those whose embarked were 'c'?
df[df['Embarked'] == 'C']['Age'].hist(bins=16)

# %%
df[df['Embarked'] == 'C']['Age'].plot(kind= 'kde')

# %%
df['Embarked'].describe()
# Out:
# count     889
# unique      3
# top         S
# freq      644
# Name: Embarked, dtype: object

# %%
df['Embarked'].nunique()
# Out:
# 3

# %%
ls_embark =  df['Embarked'].dropna().values

# %%
len(ls_embark)
# Out:
# 889

# %%
ls_embark[:10]
# Out:
# array(['S', 'C', 'S', 'S', 'S', 'Q', 'S', 'S', 'S', 'C'], dtype=object)

# %%
# How many unique values does ls_embark have? What is the frequency of those unique values?

# %%
# Create a histogram dictionary by passing list into in
# ls = df.Embarked.dropna()
# ls.values
# hist = {}

# %%
# df['Embarked'].describe()
# df['Embarked'].values_counts()

# %%
df['Embarked'].describe()
# Out:
# count     889
# unique      3
# top         S
# freq      644
# Name: Embarked, dtype: object

# %%
df['Embarked'].nunique()
# Out:
# 3

# %%
df['Embarked'].value_counts().plot(kind='bar')

# %%
import seaborn as sns

# %%
# Bar Chart Example #1 (Simple): Categorical Variables Showing Counts
sns.countplot(x="Embarked", palette="spring", data=df)

# %%
# How many female and male passangers we had in the titanic?

# %%
dict(df['Sex'].value_counts())
# Out:
# {'male': 577, 'female': 314}

# %%
df['Sex'].value_counts().to_json()
# Out:
# '{"male":577,"female":314}'

# %%
# bar
df['Sex'].value_counts().plot(kind='bar')

# %%
# pie
df['Sex'].value_counts().plot(kind='pie')

# %%
# Plot histogram of age for two different sexes for those who embarked section C

# %%
df[df['Embarked'] == 'C'].groupby('Sex')['Age'].hist(bins = 16, alpha = 0.5)
# Out:
# Sex
# female    AxesSubplot(0.125,0.125;0.775x0.755)
# male      AxesSubplot(0.125,0.125;0.775x0.755)
# Name: Age, dtype: object

# %%
# using .plot
df[df['Embarked'] == 'C'].groupby('Sex')['Age'].plot(bins = 16, kind='hist', alpha = 0.5)
# Out:
# Sex
# female    AxesSubplot(0.125,0.125;0.775x0.755)
# male      AxesSubplot(0.125,0.125;0.775x0.755)
# Name: Age, dtype: object

# %%
df[df['Embarked'] == 'C'].groupby('Sex')['Age'].value_counts()
# Out:
# Sex     Age
# female  24.00    5
#         17.00    3
#         18.00    3
#         30.00    3
#         0.75     2
#         14.00    2
#         15.00    2
#         22.00    2
#         23.00    2
#         38.00    2
#         39.00    2
#         44.00    2
#         50.00    2
#         54.00    2
#         1.00     1
#         3.00     1
#         4.00     1
#         5.00     1
#         9.00     1
#         13.00    1
#         14.50    1
#         16.00    1
#         19.00    1
#         21.00    1
#         27.00    1
#         28.00    1
#         29.00    1
#         31.00    1
#         32.00    1
#         35.00    1
#         36.00    1
#         40.00    1
#         41.00    1
#         42.00    1
#         45.00    1
#         48.00    1
#         49.00    1
#         52.00    1
#         56.00    1
#         58.00    1
#         60.00    1
# male    25.00    4
#         30.00    4
#         20.00    3
#         22.00    3
#         26.00    3
# ...

# %%
# another way to represent female, male and age for each in section C
dict(df[df['Embarked'] == 'C'].groupby('Sex')['Age'].value_counts())
# Out:
# {('female', 24.0): 5,
#  ('female', 17.0): 3,
#  ('female', 18.0): 3,
#  ('female', 30.0): 3,
#  ('female', 0.75): 2,
#  ('female', 14.0): 2,
#  ('female', 15.0): 2,
#  ('female', 22.0): 2,
#  ('female', 23.0): 2,
#  ('female', 38.0): 2,
#  ('female', 39.0): 2,
#  ('female', 44.0): 2,
#  ('female', 50.0): 2,
#  ('female', 54.0): 2,
#  ('female', 1.0): 1,
#  ('female', 3.0): 1,
#  ('female', 4.0): 1,
#  ('female', 5.0): 1,
#  ('female', 9.0): 1,
#  ('female', 13.0): 1,
#  ('female', 14.5): 1,
#  ('female', 16.0): 1,
#  ('female', 19.0): 1,
#  ('female', 21.0): 1,
#  ('female', 27.0): 1,
#  ('female', 28.0): 1,
#  ('female', 29.0): 1,
#  ('female', 31.0): 1,
#  ('female', 32.0): 1,
#  ('female', 35.0): 1,
#  ('female', 36.0): 1,
#  ('female', 40.0): 1,
#  ('female', 41.0): 1,
#  ('female', 42.0): 1,
#  ('female', 45.0): 1,
#  ('female', 48.0): 1,
#  ('female', 49.0): 1,
#  ('female', 52.0): 1,
#  ('female', 56.0): 1,
#  ('female', 58.0): 1,
#  ('female', 60.0): 1,
# ...

# %%
# What is the average age for female and male (based on sex) for those who have 'embarked' on section 'C''?

# %%
df[df['Embarked'] == 'C'].groupby('Sex')['Age'].mean()
# Out:
# Sex
# female    28.344262
# male      32.998841
# Name: Age, dtype: float64

# %%
# regression plot
sns.regplot(x='Age', y='Fare', fit_reg=False, data=df)

# %%
df.plot.scatter(x='Age', y='Fare')

# %%
sns.barplot(x='Sex', y='Survived', hue='Pclass', data=df)

# %%
df.groupby('Sex').plot.scatter(x='Age', y='Fare')
# Out:
# Sex
# female    AxesSubplot(0.125,0.125;0.775x0.755)
# male      AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
sns.countplot('Sex', hue='Pclass', data=df)

# %%
# Plot how many male or female were in different passenger classes for those who embarked section C?

import seaborn as sns

sns.countplot('Sex', hue='Pclass', data=df[df['Embarked'] == 'C'])

# %%
# Plot how many male or female were in different passenger classes for those who embarked section C or survived?

# %%
sns.countplot('Sex', hue='Pclass', data=df[(df['Embarked'] == 'C') & (df['Survived'] == 1)])

# %%
df[(df['Embarked'] == 'C') & (df['Survived'] == 1)].head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 9            10         1       2
# 19           20         1       3
# 31           32         1       1
# 36           37         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 19                            Masselmani, Mrs. Fatima  female   NaN      0
# 31     Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 36                                   Mamee, Mr. Hanna    male   NaN      0
#
#     Parch    Ticket      Fare Cabin Embarked  Gender
# 1       0  PC 17599   71.2833   C85        C       0
# 9       0    237736   30.0708   NaN        C       0
# 19      0      2649    7.2250   NaN        C       0
# 31      0  PC 17569  146.5208   B78        C       0
# ...
